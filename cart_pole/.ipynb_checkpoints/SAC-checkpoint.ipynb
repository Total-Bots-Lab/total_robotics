# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# all the dependencies
import gym
from ray.rllib.algorithms.sac import SACConfig
from ray.rllib.algorithms.algorithm import Algorithm
from ray.tune.logger import pretty_print
import numpy as np
import os
import pandas as pd
import matplotlib as plt
# Out:
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
# name of the environment
env_name = "CartPole-v1"
env = gym.make("CartPole-v1", render_mode='human')  # import the Lunar Lander environment

# %%
.training(n_step=250,
              gamma=0.99,
              model = {'vf_share_layers': False},
              q_model_config = {'fcnet_hiddens': [256, 256],
                                'fcnet_activation': 'relu',
                               },
              policy_model_config = {'fcnet_hiddens': [256, 256],
                                     'fcnet_activation': 'relu'
                                    }
             )

# %%
# Configuring an Agent: This agent use Defatlt settings from RayRLlib 
# Name: agent_default

config = (
    # The RL algorithm
    SACConfig()                       
    # The gym Env
    .environment(env_name)           
    # Numbers of rollout workers
    .rollouts(num_rollout_workers = 1)
    # Use "torch" for using pytorch or "tf" or "tf2" for Tensor Flow. "tf2" is not working for the time being.
    .framework("tf")
    # Numbers of evalution workers
    .evaluation(evaluation_num_workers=1)
    
)

#Building the agent with the configurations mentioned above
agent = config.build()
check_point = "SAC_agents/0"
agent.save(check_point)
# Out:
# 2024-04-08 22:07:30,161	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=15716) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=15716)   "class": algorithms.Blowfish,
# 2024-04-08 22:07:41,015	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=24032) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=24032)   "class": algorithms.Blowfish,
# 2024-04-08 22:07:52,834	INFO trainable.py:164 -- Trainable.setup took 22.661 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-08 22:07:52,837	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# TrainingResult(checkpoint=Checkpoint(filesystem=local, path=SAC_agents/0), metrics={})

# %%
if os.path.exists('SAC_logs') is False:
    os.mkdir('SAC_logs/')

if os.path.exists('SAC_logs/logs') is False:
    columns = ['agent_name','itr_steps','rew_mean','rew_max','rew_min']
    df = pd.DataFrame(columns=columns)
    df.to_csv('SAC_logs/logs', index=False)
    print(df)
# Out:
# Empty DataFrame
# Columns: [agent_name, itr_steps, rew_mean, rew_max, rew_min]
# Index: []

# %%
# Recall the last trained agent
agent_name_list = os.listdir('SAC_agents')
agent_name_list_in_int = [int(x) for x in agent_name_list]
last_agent_num = max(agent_name_list_in_int)
check_point = 'SAC_agents/' + str(last_agent_num)
agent = Algorithm.from_checkpoint(check_point)
result = agent.train()
result
# Out:
# 2024-04-08 22:08:22,040	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=22060) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=22060)   "class": algorithms.Blowfish,
# 2024-04-08 22:08:32,674	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=22428) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=22428)   "class": algorithms.Blowfish,
# 2024-04-08 22:08:45,577	INFO trainable.py:164 -- Trainable.setup took 23.532 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-08 22:08:45,579	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# {'custom_metrics': {},
#  'episode_media': {},
#  'info': {'learner': {'default_policy': {'learner_stats': {'mean_td_error': 17.57282,
#      'actor_loss': -60.558624,
#      'critic_loss': 17.074718,
#      'alpha_loss': -0.117951006,
#      'alpha_value': 5.036329,
#      'target_entropy': 0.6792842388153076,
#      'mean_q': 56.574516,
#      'max_q': 70.42265,
#      'min_q': 4.0559177,
#      'model': {}},
#     'td_error': array([11.566845  , 32.561558  , 29.495094  , 11.566845  ,  9.28738   ,
#            11.420738  , 11.81403   , 22.53067   , 11.5692215 , 11.880241  ,
#            27.43532   ,  6.18655   , 15.360338  ,  5.281109  , 13.549709  ,
#             2.4517746 , 38.005165  , 15.360338  , 14.509487  ,  9.341206  ,
#            30.723886  , 15.575306  , 13.300087  , 15.047716  , 16.672894  ,
#             1.9376221 ,  5.281109  ,  2.328865  ,  9.28738   , 21.519547  ,
#            24.394459  ,  6.763548  , 15.474915  , 15.537365  , 61.10295   ,
#             2.13194   , 11.571068  , 12.305382  , 21.519547  ,  6.763548  ,
#            19.321068  , 16.672894  , 11.880241  , 11.179935  , 11.5692215 ,
#            22.53067   ,  1.5410137 , 15.360338  , 16.075556  ,  8.218824  ,
#            14.595247  ,  8.642681  ,  2.13194   ,  6.763548  , 48.778786  ,
#            28.155474  ,  7.394682  ,  3.8674374 , 58.746002  , 19.321535  ,
#            16.839087  , 25.353462  , 11.740614  , 22.639088  ,  5.114338  ,
#            11.566845  , 13.820105  , 13.974716  , 62.614967  , 26.027937  ,
#            14.375301  , 56.069542  ,  8.313267  , 35.39817   , 49.000366  ,
#            48.778786  ,  3.8674374 , 56.966995  , 24.394459  , 35.39817   ,
#            11.025454  , 13.933239  ,  7.706517  , 13.562174  , 25.353462  ,
#            21.532179  , 47.77751   , 11.740614  ,  9.341206  , 11.025454  ,
#            21.522556  ,  6.13253   , 48.33322   , 38.24522   , 16.839087  ,
#             8.218824  , 10.130516  , 19.321068  , 22.884565  , 12.574299  ,
#             4.3924904 , 15.375263  , 14.870159  , 35.39817   ,  2.4517746 ,
#            18.32475   , 10.247206  , 25.678587  , 13.597923  , 26.027937  ,
#             3.819477  ,  8.512854  , 13.974716  ,  1.5410137 ,  5.114338  ,
#            11.880241  , 35.39817   , 13.492205  , 29.19585   , 58.89682   ,
#            13.300087  ,  5.5126753 , 13.605413  , 58.89682   ,  1.0628395 ,
#             4.2469826 ,  8.642681  ,  6.763548  , 14.748079  , 58.89682   ,
#            11.5692215 , 22.926155  , 30.723886  , 18.410343  , 14.196224  ,
#            18.32475   , 16.398893  , 10.957901  , 11.566845  , 10.504097  ,
#            29.495094  , 21.918327  , 14.021263  , 13.492205  ,  8.327576  ,
#             1.4361229 , 13.820105  , 16.672894  ,  3.4403458 ,  9.28738   ,
#            14.595247  ,  5.281109  , 15.36381   ,  8.327576  ,  7.0519257 ,
#            21.522556  , 62.614967  , 10.237581  , 13.7644825 ,  9.284164  ,
#            58.746002  , 11.22842   ,  9.28738   , 32.561558  , 13.349892  ,
#             8.642681  , 27.43532   , 13.349892  , 12.154045  , 13.597923  ,
#             6.6677494 , 38.24522   , 14.008055  , 30.723886  , 11.566845  ,
#            12.150375  , 16.967133  , 12.786633  , 61.10295   , 11.5692215 ,
#            20.474579  , 30.723886  , 37.420166  , 11.571068  ,  4.5684853 ,
#             8.711189  ,  2.1521645 , 13.054128  , 15.047716  , 23.257492  ,
#            20.567589  , 47.096806  , 28.488066  ,  1.3421783 , 18.410343  ,
#            28.488066  , 27.43532   , 22.53067   , 12.038742  , 19.158152  ,
#            32.561558  , 55.4457    ,  2.328865  , 11.025454  , 15.537365  ,
#             2.328865  , 12.114847  , 14.424719  , 12.574299  ,  4.8113747 ,
#             9.28738   , 11.672028  , 10.237581  , 20.153727  , 10.443649  ,
#             0.17959976, 11.179935  , 15.360338  ,  8.313267  , 14.509487  ,
#             4.5684853 ,  7.0519257 , 11.740614  ,  8.642681  , 13.492205  ,
#            16.075556  , 14.875423  ,  3.8674374 ,  6.8411674 , 12.363932  ,
#            13.349892  , 15.001078  ,  9.853243  , 13.4608    , 19.928724  ,
#            18.317535  , 21.413862  , 13.820105  , 21.522556  , 19.09283   ,
#            28.155474  ,  8.327576  ,  4.67107   , 19.321068  , 14.595247  ,
#             9.341206  , 11.566845  , 21.955692  , 13.349892  , 20.612143  ,
#            51.468422  , 11.81403   , 12.363932  ,  8.383726  , 11.22842   ,
#            31.026985  ], dtype=float32),
#     'custom_metrics': {},
#     'num_agent_steps_trained': 256.0,
#     'num_grad_updates_lifetime': 1.0,
#     'diff_num_grad_updates_vs_sampler_policy': 0.0}},
#   'num_env_steps_sampled': 1463500,
#   'num_env_steps_trained': 1497088,
#   'num_agent_steps_sampled': 1463500,
#   'num_agent_steps_trained': 1497088,
#   'last_target_update_ts': 1463500,
#   'num_target_updates': 5848},
#  'sampler_results': {'episode_reward_max': 90.0,
#   'episode_reward_min': 90.0,
#   'episode_reward_mean': 90.0,
#   'episode_len_mean': 90.0,
#   'episode_media': {},
#   'episodes_this_iter': 1,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [90.0], 'episode_lengths': [90]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 1.309773836477819,
#    'mean_inference_ms': 1.0250783061601252,
#    'mean_action_processing_ms': 0.17926417498949515,
#    'mean_env_wait_ms': 0.006216930678166241,
#    'mean_env_render_ms': 0.0},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {'ObsPreprocessorConnector_ms': 0.0,
#    'StateBufferConnector_ms': 0.0,
#    'ViewRequirementAgentConnector_ms': 0.0}},
#  'episode_reward_max': 90.0,
#  'episode_reward_min': 90.0,
#  'episode_reward_mean': 90.0,
#  'episode_len_mean': 90.0,
#  'episodes_this_iter': 1,
#  'policy_reward_min': {},
#  'policy_reward_max': {},
#  'policy_reward_mean': {},
#  'hist_stats': {'episode_reward': [90.0], 'episode_lengths': [90]},
#  'sampler_perf': {'mean_raw_obs_processing_ms': 1.309773836477819,
#   'mean_inference_ms': 1.0250783061601252,
#   'mean_action_processing_ms': 0.17926417498949515,
#   'mean_env_wait_ms': 0.006216930678166241,
#   'mean_env_render_ms': 0.0},
#  'num_faulty_episodes': 0,
#  'connector_metrics': {'ObsPreprocessorConnector_ms': 0.0,
#   'StateBufferConnector_ms': 0.0,
#   'ViewRequirementAgentConnector_ms': 0.0},
#  'num_healthy_workers': 1,
#  'num_in_flight_async_reqs': 0,
#  'num_remote_worker_restarts': 0,
#  'num_agent_steps_sampled': 1463500,
#  'num_agent_steps_trained': 1497088,
#  'num_env_steps_sampled': 1463500,
#  'num_env_steps_trained': 1497088,
#  'num_env_steps_sampled_this_iter': 250,
#  'num_env_steps_trained_this_iter': 256,
#  'num_env_steps_sampled_throughput_per_sec': 113.12628282757449,
#  'num_env_steps_trained_throughput_per_sec': 115.84131361543628,
#  'timesteps_total': 1463500,
#  'num_steps_trained_this_iter': 256,
#  'agent_timesteps_total': 1463500,
#  'timers': {'training_iteration_time_ms': 2209.92,
#   'sample_time_ms': 640.172,
#   'load_time_ms': 0.0,
#   'load_throughput': 0.0,
#   'learn_time_ms': 319.795,
#   'learn_throughput': 800.512,
#   'synch_weights_time_ms': 0.0},
#  'counters': {'num_env_steps_sampled': 1463500,
#   'num_env_steps_trained': 1497088,
#   'num_agent_steps_sampled': 1463500,
#   'num_agent_steps_trained': 1497088,
#   'last_target_update_ts': 1463500,
#   'num_target_updates': 5848},
#  'done': False,
#  'episodes_total': 1,
#  'training_iteration': 3046,
#  'trial_id': 'default',
#  'date': '2024-04-08_22-08-48',
#  'timestamp': 1712594328,
#  'time_this_iter_s': 2.2207729816436768,
#  'time_total_s': 2.2207729816436768,
#  'pid': 23824,
#  'hostname': 'Ritwik',
#  'node_ip': '127.0.0.1',
#  'config': {'extra_python_environs_for_driver': {},
#   'extra_python_environs_for_worker': {},
#   'num_gpus': 0,
#   'num_cpus_per_worker': 1,
#   'num_gpus_per_worker': 0,
#   '_fake_gpus': False,
#   'num_learner_workers': 0,
#   'num_gpus_per_learner_worker': 0,
#   'num_cpus_per_learner_worker': 1,
#   'local_gpu_idx': 0,
#   'custom_resources_per_worker': {},
#   'placement_strategy': 'PACK',
#   'eager_tracing': True,
#   'eager_max_retraces': 20,
#   'tf_session_args': {'intra_op_parallelism_threads': 2,
#    'inter_op_parallelism_threads': 2,
#    'gpu_options': {'allow_growth': True},
#    'log_device_placement': False,
#    'device_count': {'CPU': 1},
#    'allow_soft_placement': True},
#   'local_tf_session_args': {'intra_op_parallelism_threads': 8,
#    'inter_op_parallelism_threads': 8},
#   'torch_compile_learner': False,
#   'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#   'torch_compile_learner_dynamo_backend': 'inductor',
#   'torch_compile_learner_dynamo_mode': None,
#   'torch_compile_worker': False,
#   'torch_compile_worker_dynamo_backend': 'onnxrt',
#   'torch_compile_worker_dynamo_mode': None,
#   'env': 'CartPole-v1',
#   'env_config': {},
#   'observation_space': None,
#   'action_space': None,
#   'env_task_fn': None,
#   'render_env': False,
#   'clip_rewards': None,
#   'normalize_actions': True,
#   'clip_actions': False,
#   'disable_env_checking': False,
#   'auto_wrap_old_gym_envs': True,
#   'action_mask_key': 'action_mask',
#   '_is_atari': None,
#   'env_runner_cls': None,
#   'num_envs_per_worker': 1,
#   'enable_connectors': True,
#   '_env_to_module_connector': None,
#   '_module_to_env_connector': None,
#   'add_default_connectors_to_env_to_module_pipeline': True,
#   'add_default_connectors_to_module_to_env_pipeline': True,
#   'episode_lookback_horizon': 1,
#   'rollout_fragment_length': 'auto',
#   'batch_mode': 'truncate_episodes',
#   'validate_workers_after_construction': True,
#   'compress_observations': False,
#   'sampler_perf_stats_ema_coef': None,
#   'sample_async': -1,
#   'remote_worker_envs': False,
#   'remote_env_batch_wait_ms': 0,
#   'enable_tf1_exec_eagerly': False,
#   'sample_collector': ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector,
#   'preprocessor_pref': 'deepmind',
#   'observation_filter': 'NoFilter',
#   'update_worker_filter_stats': True,
#   'use_worker_filter_stats': True,
#   'gamma': 0.99,
#   'lr': [[0, 0.01], [500, 0.001], [1000, 0.0001], [2000, 1e-05]],
#   'grad_clip': None,
#   'grad_clip_by': 'global_norm',
#   'train_batch_size': 256,
#   'train_batch_size_per_learner': None,
#   'model': {'_disable_preprocessor_api': False,
#    '_disable_action_flattening': False,
#    'fcnet_hiddens': [256, 256],
#    'fcnet_activation': 'tanh',
#    'fcnet_weights_initializer': None,
#    'fcnet_weights_initializer_config': None,
#    'fcnet_bias_initializer': None,
#    'fcnet_bias_initializer_config': None,
#    'conv_filters': None,
#    'conv_activation': 'relu',
#    'conv_kernel_initializer': None,
#    'conv_kernel_initializer_config': None,
#    'conv_bias_initializer': None,
#    'conv_bias_initializer_config': None,
#    'conv_transpose_kernel_initializer': None,
#    'conv_transpose_kernel_initializer_config': None,
#    'conv_transpose_bias_initializer': None,
#    'conv_transpose_bias_initializer_config': None,
#    'post_fcnet_hiddens': [],
#    'post_fcnet_activation': 'relu',
#    'post_fcnet_weights_initializer': None,
#    'post_fcnet_weights_initializer_config': None,
#    'post_fcnet_bias_initializer': None,
#    'post_fcnet_bias_initializer_config': None,
#    'free_log_std': False,
#    'no_final_linear': False,
#    'vf_share_layers': True,
#    'use_lstm': False,
#    'max_seq_len': 20,
#    'lstm_cell_size': 256,
#    'lstm_use_prev_action': False,
#    'lstm_use_prev_reward': False,
#    'lstm_weights_initializer': None,
#    'lstm_weights_initializer_config': None,
#    'lstm_bias_initializer': None,
#    'lstm_bias_initializer_config': None,
#    '_time_major': False,
#    'use_attention': False,
#    'attention_num_transformer_units': 1,
#    'attention_dim': 64,
#    'attention_num_heads': 1,
#    'attention_head_dim': 32,
#    'attention_memory_inference': 50,
#    'attention_memory_training': 50,
#    'attention_position_wise_mlp_dim': 32,
#    'attention_init_gru_gate_bias': 2.0,
#    'attention_use_n_prev_actions': 0,
#    'attention_use_n_prev_rewards': 0,
#    'framestack': True,
#    'dim': 84,
#    'grayscale': False,
#    'zero_mean': True,
#    'custom_model': None,
#    'custom_model_config': {},
#    'custom_action_dist': None,
#    'custom_preprocessor': None,
#    'encoder_latent_dim': None,
#    'always_check_shapes': False,
#    'lstm_use_prev_action_reward': -1,
#    '_use_default_native_models': -1},
#   '_learner_connector': None,
#   'add_default_connectors_to_learner_pipeline': True,
#   'optimizer': {},
#   'max_requests_in_flight_per_sampler_worker': 2,
#   '_learner_class': None,
#   'explore': True,
#   'exploration_config': {'type': 'StochasticSampling'},
#   'algorithm_config_overrides_per_module': {},
#   '_per_module_overrides': {},
#   'count_steps_by': 'env_steps',
#   'policy_map_capacity': 100,
#   'policy_mapping_fn': <function ray.rllib.algorithms.algorithm_config.AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN(aid, episode, worker, **kwargs)>,
#   'policies_to_train': None,
#   'policy_states_are_swappable': False,
#   'observation_fn': None,
#   'input_config': {},
#   'actions_in_input_normalized': False,
#   'postprocess_inputs': False,
#   'shuffle_buffer_size': 0,
#   'output': None,
#   'output_config': {},
#   'output_compress_columns': ['obs', 'new_obs'],
#   'output_max_file_size': 67108864,
#   'offline_sampling': False,
#   'evaluation_interval': None,
#   'evaluation_duration': 10,
#   'evaluation_duration_unit': 'episodes',
#   'evaluation_sample_timeout_s': 180.0,
#   'evaluation_parallel_to_training': False,
#   'evaluation_config': None,
#   'off_policy_estimation_methods': {},
#   'ope_split_batch_by_episode': True,
#   'evaluation_num_workers': 1,
#   'custom_async_evaluation_function': None,
#   'always_attach_evaluation_results': False,
#   'enable_async_evaluation': False,
#   'in_evaluation': False,
#   'sync_filters_on_rollout_workers_timeout_s': 60.0,
#   'keep_per_episode_custom_metrics': False,
#   'metrics_episode_collection_timeout_s': 60.0,
#   'metrics_num_episodes_for_smoothing': 100,
#   'min_time_s_per_iteration': 1,
#   'min_train_timesteps_per_iteration': 0,
#   'min_sample_timesteps_per_iteration': 100,
#   'export_native_model_files': False,
#   'checkpoint_trainable_policies_only': False,
#   'logger_creator': None,
#   'logger_config': None,
#   'log_level': 'WARN',
#   'log_sys_usage': True,
#   'fake_sampler': False,
#   'seed': None,
#   'ignore_worker_failures': False,
#   'recreate_failed_workers': False,
#   'max_num_worker_restarts': 1000,
#   'delay_between_worker_restarts_s': 60.0,
#   'restart_failed_sub_environments': False,
#   'num_consecutive_worker_failures_tolerance': 100,
#   'worker_health_probe_timeout_s': 60,
#   'worker_restore_timeout_s': 1800,
#   '_rl_module_spec': None,
#   '_AlgorithmConfig__prior_exploration_config': None,
#   '_enable_new_api_stack': False,
#   '_tf_policy_handles_more_than_one_loss': False,
#   '_disable_preprocessor_api': False,
#   '_disable_action_flattening': False,
#   '_disable_initialize_loss_from_dummy_batch': False,
#   'simple_optimizer': False,
#   'policy_map_cache': -1,
#   'worker_cls': -1,
#   'synchronize_filters': -1,
#   'replay_sequence_length': None,
#   '_disable_execution_plan_api': -1,
#   'twin_q': True,
#   'q_model_config': {'fcnet_hiddens': [256, 256],
#    'fcnet_activation': 'relu',
#    'post_fcnet_hiddens': [],
#    'post_fcnet_activation': None,
#    'custom_model': None,
#    'custom_model_config': {}},
#   'policy_model_config': {'fcnet_hiddens': [256, 256],
#    'fcnet_activation': 'relu',
#    'post_fcnet_hiddens': [],
#    'post_fcnet_activation': None,
#    'custom_model': None,
#    'custom_model_config': {}},
#   'tau': 0.005,
#   'initial_alpha': 1.0,
#   'target_entropy': 'auto',
#   'n_step': 250,
#   'replay_buffer_config': {'_enable_replay_buffer_api': True,
#    'type': 'MultiAgentPrioritizedReplayBuffer',
#    'capacity': 1000000,
#    'prioritized_replay': False,
#    'prioritized_replay_alpha': 0.6,
#    'prioritized_replay_beta': 0.4,
#    'prioritized_replay_eps': 1e-06,
#    'worker_side_prioritization': False},
#   'store_buffer_in_checkpoints': False,
#   'training_intensity': None,
#   'optimization': {'actor_learning_rate': 0.0003,
#    'critic_learning_rate': 0.0003,
#    'entropy_learning_rate': 0.0003},
#   'target_network_update_freq': 0,
#   'num_steps_sampled_before_learning_starts': 1500,
#   '_deterministic_loss': False,
#   '_use_beta_distribution': False,
#   'use_state_preprocessor': -1,
#   'worker_side_prioritization': -1,
#   'input': 'sampler',
#   'policies': {'default_policy': (None, None, None, None)},
#   'callbacks': ray.rllib.algorithms.callbacks.DefaultCallbacks,
#   'create_env_on_driver': False,
#   'custom_eval_function': None,
#   'framework': 'tf',
#   'num_cpus_for_driver': 1,
#   'num_workers': 1},
#  'time_since_restore': 2.2207729816436768,
#  'iterations_since_restore': 1,
#  'perf': {'cpu_util_percent': 10.275, 'ram_util_percent': 81.42500000000001}}

# %%
result['info']['learner']
# Out:
# {'default_policy': {'learner_stats': {'mean_td_error': 12.281498,
#    'actor_loss': -53.548653,
#    'critic_loss': 11.789717,
#    'alpha_loss': -0.1373182,
#    'alpha_value': 5.036329,
#    'target_entropy': 0.6792842388153076,
#    'mean_q': 49.477577,
#    'max_q': 69.0623,
#    'min_q': 6.570903,
#    'model': {}},
#   'td_error': array([16.49292   , 24.946836  ,  1.2422028 ,  7.890465  , 15.022379  ,
#          18.822987  ,  1.6112175 ,  9.905565  ,  7.841181  , 13.345137  ,
#           7.890465  ,  3.8891153 ,  1.6112175 , 13.205513  ,  3.4024143 ,
#          14.259808  ,  0.07129288,  0.54538345, 18.409351  , 17.168324  ,
#           1.7026043 ,  4.623913  ,  1.3855553 ,  6.8808327 , 35.735237  ,
#          12.364382  ,  9.214403  , 10.118069  , 14.046852  ,  9.905565  ,
#           6.9012184 ,  7.1589355 ,  1.9561167 , 12.643284  ,  5.0733585 ,
#          19.218458  , 10.188362  , 11.8011    , 15.514648  , 10.147663  ,
#           4.931862  ,  9.498415  , 13.776482  , 14.152107  ,  9.974167  ,
#          27.71791   ,  6.7545433 ,  1.2063065 , 28.75028   , 20.851896  ,
#          10.402683  ,  4.7843704 ,  9.733669  , 26.75591   , 24.983738  ,
#          19.824696  , 18.317493  , 13.025757  , 24.946836  , 28.75028   ,
#          12.416344  , 12.452621  , 14.152107  ,  9.274498  ,  1.3855553 ,
#          26.110575  , 16.769783  ,  8.470787  , 20.027952  , 12.119635  ,
#           6.684103  , 12.119635  ,  2.9382954 , 19.922981  ,  7.1589355 ,
#          14.448145  ,  5.617489  ,  8.8429165 , 10.118069  , 15.442678  ,
#          11.274567  ,  6.3528004 ,  1.4131908 , 20.594633  ,  9.306129  ,
#          13.446003  ,  8.470787  ,  1.9651184 , 12.452621  ,  0.41423035,
#           8.319336  , 20.851896  , 10.004635  , 14.259808  ,  9.5913315 ,
#          11.203043  ,  9.733669  , 12.070213  , 14.328619  ,  5.0170765 ,
#          18.887823  , 11.204559  , 16.485605  ,  9.130928  ,  5.1610584 ,
#          22.145813  ,  8.811026  , 14.448145  ,  6.384533  , 19.29953   ,
#          24.469936  , 20.027952  ,  3.4024143 , 15.514648  , 20.603504  ,
#          13.332268  ,  6.726925  , 32.703114  , 25.232222  ,  7.890465  ,
#           9.214403  ,  2.6763535 , 11.021004  , 17.168324  ,  6.684103  ,
#          25.563694  , 11.021004  ,  1.1826725 , 20.594633  , 12.364382  ,
#          13.345137  , 20.603504  , 10.402683  , 28.75028   , 23.298164  ,
#          14.088139  , 13.025757  , 11.026388  , 17.90359   , 16.949608  ,
#          24.946836  , 13.510778  ,  1.2052574 ,  3.9248161 , 20.027191  ,
#           5.623337  , 11.203043  ,  1.9621296 , 11.415613  , 11.501369  ,
#          17.97166   ,  0.41423035,  7.4733734 , 21.382835  ,  1.7026043 ,
#          15.514648  ,  5.2770786 ,  8.319336  , 35.735237  , 20.027952  ,
#          22.145813  ,  3.4024143 ,  3.7689877 ,  3.4024143 ,  9.130928  ,
#           3.7689877 , 12.643284  , 13.332268  , 17.691046  ,  3.0845165 ,
#          18.317493  ,  3.9248161 , 25.232222  , 22.156494  , 12.119635  ,
#          16.987753  , 13.776482  ,  5.062811  , 16.63979   ,  8.811026  ,
#           1.9651184 , 16.949608  , 15.064917  , 19.985409  ,  8.481354  ,
#           8.92737   , 11.415613  ,  8.920616  , 25.563694  ,  1.1826725 ,
#          15.022379  ,  8.92737   ,  9.154751  ,  5.617489  , 13.523098  ,
#          14.046852  , 12.358078  , 26.75591   ,  8.811026  ,  8.725864  ,
#          11.793369  ,  6.684103  ,  1.9651184 , 14.328619  ,  6.3528004 ,
#          10.402683  , 13.446003  , 16.56413   , 19.29953   ,  4.025879  ,
#           5.4657364 ,  9.274498  ,  7.890465  , 19.013422  ,  2.6763535 ,
#           9.905565  , 17.600107  , 17.97166   , 25.232222  , 23.17734   ,
#          18.887823  , 22.89651   , 20.027952  , 10.402683  ,  1.2063065 ,
#           2.470625  , 20.603504  ,  8.725864  , 20.126432  , 11.274567  ,
#          20.027191  , 24.983738  , 19.184072  , 10.4248085 ,  0.2182579 ,
#           4.623913  , 16.56413   ,  6.161728  , 19.404074  , 20.851896  ,
#          13.332268  , 13.776482  ,  8.481354  , 18.409351  ,  6.5962963 ,
#           9.260839  ,  4.623913  ,  0.07129288, 24.57512   ,  5.2770786 ,
#           5.4657364 , 14.328619  ,  1.2927189 ,  6.384533  , 13.510778  ,
#          11.021004  ], dtype=float32),
#   'custom_metrics': {},
#   'num_agent_steps_trained': 256.0,
#   'num_grad_updates_lifetime': 1.0,
#   'diff_num_grad_updates_vs_sampler_policy': 0.0}}

# %%
# Recall the last trained agent
agent_name_list = os.listdir('SAC_agents')
agent_name_list_in_int = [int(x) for x in agent_name_list]
last_agent_num = max(agent_name_list_in_int)
check_point = 'SAC_agents/' + str(last_agent_num)
agent = Algorithm.from_checkpoint(check_point)

# Recall the log data frame
logs = pd.read_csv('SAC_logs/logs')

training_range = 2000

for i in range(last_agent_num, (last_agent_num + training_range)):
    # Train the agent
    result = agent.train()
    # Save the agent
    check_point_path_name = 'SAC_agents/' + str(i+1)
    agent.save(check_point_path_name)
    # Capture the log    
    #print(pretty_print(result)) # It gives all the parameters regarding the training
    logs.at[i,'agent_name'] = str(i+1)
    logs.at[i,'itr_steps'] = result['num_agent_steps_sampled'] * (i+1)
    logs.at[i,'rew_mean'] = result['episode_reward_mean']
    logs.at[i,'rew_max'] = result['episode_reward_max']
    logs.at[i,'rew_min'] = result['episode_reward_min']
    
    #print(logs)
    logs.to_csv('SAC_logs/logs', index=False)
# Out:
# 2024-04-08 11:32:13,477	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/simple_q/` has been deprecated. Use `rllib_contrib/simple_q/` instead. This will raise an error in the future!
# 2024-04-08 11:32:13,478	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:500: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-04-08 11:32:16,411	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (pid=6600) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=6600)   "class": algorithms.Blowfish,
# 2024-04-08 11:32:32,119	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=17680) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=17680)   "class": algorithms.Blowfish,
# 2024-04-08 11:32:45,037	INFO trainable.py:164 -- Trainable.setup took 31.482 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-08 11:32:45,039	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# 2024-04-08 11:32:46,435	WARNING multi_agent_prioritized_replay_buffer.py:215 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.
# 2024-04-08 11:32:46,660	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# C:\Users\ritwi\AppData\Local\Temp\ipykernel_2244\4216477224.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1227' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   logs.at[i,'agent_name'] = str(i+1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      11 training_range = 2000
#      13 for i in range(last_agent_num, (last_agent_num + training_range)):
#      14     # Train the agent
# ---> 15     result = agent.train()
#      16     # Save the agent
#      17     check_point_path_name = 'SAC_agents/' + str(i+1)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\tune\trainable\trainable.py:331, in Trainable.train(self)
#     329 start = time.time()
#     330 try:
# --> 331     result = self.step()
#     332 except Exception as e:
#     333     skipped = skip_exceptions(e)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:849, in Algorithm.step(self)
#     841     (
#     842         results,
#     843         train_iter_ctx,
#     844     ) = self._run_one_training_iteration_and_evaluation_in_parallel()
#     845 # - No evaluation necessary, just run the next training iteration.
#     846 # - We have to evaluate in this training iteration, but no parallelism ->
#     847 #   evaluate after the training iteration is entirely done.
#     848 else:
# --> 849     results, train_iter_ctx = self._run_one_training_iteration()
#     851 # Sequential: Train (already done above), then evaluate.
#     852 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:3194, in Algorithm._run_one_training_iteration(self)
#    3191     while not train_iter_ctx.should_stop(results):
#    3192         # Try to train one step.
#    3193         with self._timers[TRAINING_ITERATION_TIMER]:
# -> 3194             results = self.training_step()
#    3196 # With training step done. Try to bring failed workers back.
#    3197 self.restore_workers(self.workers)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\sac\sac.py:455, in SAC.training_step(self)
#     450 @override(DQN)
#     451 def training_step(self) -> ResultDict:
#     452     # If `RolloutWorker` is used, fall back to the old stack `training step`
#     453     # of `DQN`.
#     454     if not self.config.uses_new_env_runners:
# --> 455         return super().training_step()
#     457     # Alternate between storing and sampling and training.
#     458     store_weight, sample_and_train_weight = calculate_rr_weights(self.config)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\dqn\dqn.py:385, in DQN.training_step(self)
#     382 for _ in range(store_weight):
#     383     # Sample (MultiAgentBatch) from workers.
#     384     with self._timers[SAMPLE_TIMER]:
# --> 385         new_sample_batch = synchronous_parallel_sample(
#     386             worker_set=self.workers, concat=True
#     387         )
#     389     # Update counters
#     390     self._counters[NUM_AGENT_STEPS_SAMPLED] += new_sample_batch.agent_steps()
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\execution\rollout_ops.py:88, in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat, uses_new_env_runners)
#      85     sampled_data = [worker_set.local_worker().sample()]
#      86 # Loop over remote workers' `sample()` method in parallel.
#      87 else:
# ---> 88     sampled_data = worker_set.foreach_worker(
#      89         lambda w: w.sample(), local_worker=False, healthy_only=True
#      90     )
#      91     if worker_set.num_healthy_remote_workers() <= 0:
#      92         # There is no point staying in this loop, since we will not be able to
#      93         # get any new samples if we don't have any healthy remote workers left.
#      94         break
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\evaluation\worker_set.py:762, in WorkerSet.foreach_worker(self, func, local_worker, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     759 if not self.__worker_manager.actor_ids():
#     760     return local_result
# --> 762 remote_results = self.__worker_manager.foreach_actor(
#     763     func,
#     764     healthy_only=healthy_only,
#     765     remote_actor_ids=remote_worker_ids,
#     766     timeout_seconds=timeout_seconds,
#     767     return_obj_refs=return_obj_refs,
#     768     mark_healthy=mark_healthy,
#     769 )
#     771 handle_remote_call_result_errors(remote_results, self._ignore_worker_failures)
#     773 # With application errors handled, return good results.
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\actor_manager.py:609, in FaultTolerantActorManager.foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     600     func, remote_actor_ids = self._filter_func_and_remote_actor_id_by_state(
#     601         func, remote_actor_ids
#     602     )
#     604 remote_calls = self._call_actors(
#     605     func=func,
#     606     remote_actor_ids=remote_actor_ids,
#     607 )
# --> 609 _, remote_results = self._fetch_result(
#     610     remote_actor_ids=remote_actor_ids,
#     611     remote_calls=remote_calls,
#     612     tags=[None] * len(remote_calls),
#     613     timeout_seconds=timeout_seconds,
#     614     return_obj_refs=return_obj_refs,
#     615     mark_healthy=mark_healthy,
#     616 )
#     618 return remote_results
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\actor_manager.py:476, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     473 if not remote_calls:
#     474     return [], RemoteCallResults()
# --> 476 ready, _ = ray.wait(
#     477     remote_calls,
#     478     num_returns=len(remote_calls),
#     479     timeout=timeout,
#     480     # Make sure remote results are fetched locally in parallel.
#     481     fetch_local=not return_obj_refs,
#     482 )
#     484 # Remote data should already be fetched to local object store at this point.
#     485 remote_results = RemoteCallResults()
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\_private\auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\_private\worker.py:2898, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    2896 timeout = timeout if timeout is not None else 10**6
#    2897 timeout_milliseconds = int(timeout * 1000)
# -> 2898 ready_ids, remaining_ids = worker.core_worker.wait(
#    2899     ray_waitables,
#    2900     num_returns,
#    2901     timeout_milliseconds,
#    2902     worker.current_task_id,
#    2903     fetch_local,
#    2904 )
#    2905 return ready_ids, remaining_ids
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
logs = pd.read_csv('SAC_logs/logs')

# Plotting Column1 and Column2 with Time as the x-axis
plt.plot(logs['itr_steps'], logs['rew_mean'], label='rew_mean')
plt.plot(logs['itr_steps'], logs['rew_max'], label='rew_max')
plt.plot(logs['itr_steps'], logs['rew_min'], label='rew_min')

# Adding labels and legend
plt.xlabel('Iteration_Steps')
plt.ylabel('Values')
plt.legend()

# Display the plot
plt.show()

# %%
# recall and trained agent
check_point = "SAC_agents/2110"
agent = Algorithm.from_checkpoint(check_point)
# Out:
# 2024-04-07 22:32:23,902	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:500: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=6516) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=6516)   "class": algorithms.Blowfish,
# 2024-04-07 22:32:34,225	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=10188) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=10188)   "class": algorithms.Blowfish,
# 2024-04-07 22:32:45,869	INFO trainable.py:164 -- Trainable.setup took 21.962 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-07 22:32:45,871	WARNING util.py:62 -- Install gputil for GPU system monitoring.

# %%
# use the restored agent in the environment
env = gym.make("CartPole-v1", render_mode='human')
for j in range(20):
    observation = np.array(env.reset()[0])
    done = False
    score = 0
    while not done:
        action = agent.compute_single_action(observation) # here is the RL agent from RAYRLlib
        observation,reward,done,info,info = env.step(action)
        score += reward
        if (score>1000):
            done = True
    print("score:",score)
env.close()
# Out:
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# score: 291.0
# score: 481.0
# score: 325.0
# score: 310.0
# score: 245.0
# score: 351.0
# score: 424.0
# score: 254.0
# score: 263.0
# score: 299.0
# score: 324.0
# score: 135.0
# score: 309.0
# score: 268.0
# score: 353.0
# score: 333.0
# score: 227.0
# score: 228.0
# score: 338.0
# score: 241.0
