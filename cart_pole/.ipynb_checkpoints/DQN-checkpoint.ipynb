# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# all the dependencies
import gym
from ray.rllib.algorithms.dqn.dqn import DQNConfig
from ray.rllib.algorithms.algorithm import Algorithm
from ray.tune.logger import pretty_print
import numpy as np
import os
import pandas as pd
import matplotlib as plt

# %%
# name of the environment
env_name = "CartPole-v1"
env = gym.make("CartPole-v1", render_mode='human')  # import the Lunar Lander environment

# %%
# Configuring an Agent: This agent use Defatlt settings from RayRLlib 
# Name: agent_default

config = (
    # The RL algorithm
    DQNConfig()                       
    # The gym Env
    .environment(env_name)           
    # Numbers of rollout workers
    .rollouts(num_rollout_workers = 1)
    # Use "torch" for using pytorch or "tf" or "tf2" for Tensor Flow. "tf2" is not working for the time being.
    .framework("tf")
    # Numbers of evalution workers
    .evaluation(evaluation_num_workers=1)
    .training(gamma =  0.95,
              n_step = 1,  
              hiddens = [512, 512])
    )

'Set the epsilon greedy coefficient'
exploration_config = {"type": "EpsilonGreedy",
                      "initial_epsilon": 1,
                      "final_epsilon": 0.01,
                      "epsilon_timesteps": 20000
                      }
config["exploration_config"] = exploration_config

#Building the agent with the configurations mentioned above
agent = config.build()
check_point = "DQN_agents/0"
agent.save(check_point)
# Out:
# 2024-04-11 16:35:17,453	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=1592) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=1592)   "class": algorithms.Blowfish,
# 2024-04-11 16:35:27,378	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=10576) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=10576)   "class": algorithms.Blowfish,
# 2024-04-11 16:35:45,099	INFO trainable.py:164 -- Trainable.setup took 27.636 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-11 16:35:45,102	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# TrainingResult(checkpoint=Checkpoint(filesystem=local, path=DQN_agents/0), metrics={})

# %%
if os.path.exists('DQN_logs') is False:
    os.mkdir('DQN_logs/')

if os.path.exists('DQN_logs/logs') is False:
    columns = ['agent_name','itr_steps','rew_mean','rew_max','rew_min']
    df = pd.DataFrame(columns=columns)
    df.to_csv('DQN_logs/logs', index=False)
    print(df)
# Out:
# Empty DataFrame
# Columns: [agent_name, itr_steps, rew_mean, rew_max, rew_min]
# Index: []

# %%
# Recall the last trained agent
agent_name_list = os.listdir('DQN_agents')
agent_name_list_in_int = [int(x) for x in agent_name_list]
last_agent_num = max(agent_name_list_in_int)
check_point = 'DQN_agents/' + str(last_agent_num)
agent = Algorithm.from_checkpoint(check_point)
result = agent.train()
result
# Out:
# 2024-04-11 16:35:45,399	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:500: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=18152) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=18152)   "class": algorithms.Blowfish,
# 2024-04-11 16:36:05,851	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=284) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=284)   "class": algorithms.Blowfish,
# 2024-04-11 16:36:28,613	INFO trainable.py:164 -- Trainable.setup took 43.204 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-11 16:36:28,617	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=18152) WARNING:tensorflow:From C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\exploration\epsilon_greedy.py:242: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (RolloutWorker pid=18152) Instructions for updating:
# (RolloutWorker pid=18152) Prefer Variable.assign which has equivalent behavior in 2.X.
# {'custom_metrics': {},
#  'episode_media': {},
#  'info': {'learner': {},
#   'num_env_steps_sampled': 1000,
#   'num_env_steps_trained': 0,
#   'num_agent_steps_sampled': 1000,
#   'num_agent_steps_trained': 0},
#  'sampler_results': {'episode_reward_max': 54.0,
#   'episode_reward_min': 9.0,
#   'episode_reward_mean': 20.142857142857142,
#   'episode_len_mean': 20.142857142857142,
#   'episode_media': {},
#   'episodes_this_iter': 49,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [31.0,
#     13.0,
#     14.0,
#     26.0,
#     54.0,
#     14.0,
#     28.0,
#     13.0,
#     16.0,
#     22.0,
#     19.0,
#     24.0,
#     17.0,
#     24.0,
#     11.0,
#     12.0,
#     17.0,
#     46.0,
#     11.0,
#     41.0,
#     9.0,
#     18.0,
#     17.0,
#     12.0,
#     30.0,
#     11.0,
#     20.0,
#     10.0,
#     10.0,
#     17.0,
#     11.0,
#     14.0,
#     10.0,
#     24.0,
#     18.0,
#     28.0,
#     17.0,
#     26.0,
#     20.0,
#     26.0,
#     42.0,
#     22.0,
#     13.0,
#     17.0,
#     20.0,
#     17.0,
#     21.0,
#     22.0,
#     12.0],
#    'episode_lengths': [31,
#     13,
#     14,
#     26,
#     54,
#     14,
#     28,
#     13,
#     16,
#     22,
#     19,
#     24,
#     17,
#     24,
#     11,
#     12,
#     17,
#     46,
#     11,
#     41,
#     9,
#     18,
#     17,
#     12,
#     30,
#     11,
#     20,
#     10,
#     10,
#     17,
#     11,
#     14,
#     10,
#     24,
#     18,
#     28,
#     17,
#     26,
#     20,
#     26,
#     42,
#     22,
#     13,
#     17,
#     20,
#     17,
#     21,
#     22,
#     12]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 1.9392986278552988,
#    'mean_inference_ms': 2.3113059235381317,
#    'mean_action_processing_ms': 0.32740730148452624,
#    'mean_env_wait_ms': 0.14817702782142175,
#    'mean_env_render_ms': 0.0},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {'ObsPreprocessorConnector_ms': 0.009781973702566964,
#    'StateBufferConnector_ms': 0.029928343636648997,
#    'ViewRequirementAgentConnector_ms': 0.3139816984838369}},
#  'episode_reward_max': 54.0,
#  'episode_reward_min': 9.0,
#  'episode_reward_mean': 20.142857142857142,
#  'episode_len_mean': 20.142857142857142,
#  'episodes_this_iter': 49,
#  'policy_reward_min': {},
#  'policy_reward_max': {},
#  'policy_reward_mean': {},
#  'hist_stats': {'episode_reward': [31.0,
#    13.0,
#    14.0,
#    26.0,
#    54.0,
#    14.0,
#    28.0,
#    13.0,
#    16.0,
#    22.0,
#    19.0,
#    24.0,
#    17.0,
#    24.0,
#    11.0,
#    12.0,
#    17.0,
#    46.0,
#    11.0,
#    41.0,
#    9.0,
#    18.0,
#    17.0,
#    12.0,
#    30.0,
#    11.0,
#    20.0,
#    10.0,
#    10.0,
#    17.0,
#    11.0,
#    14.0,
#    10.0,
#    24.0,
#    18.0,
#    28.0,
#    17.0,
#    26.0,
#    20.0,
#    26.0,
#    42.0,
#    22.0,
#    13.0,
#    17.0,
#    20.0,
#    17.0,
#    21.0,
#    22.0,
#    12.0],
#   'episode_lengths': [31,
#    13,
#    14,
#    26,
#    54,
#    14,
#    28,
#    13,
#    16,
#    22,
#    19,
#    24,
#    17,
#    24,
#    11,
#    12,
#    17,
#    46,
#    11,
#    41,
#    9,
#    18,
#    17,
#    12,
#    30,
#    11,
#    20,
#    10,
#    10,
#    17,
#    11,
#    14,
#    10,
#    24,
#    18,
#    28,
#    17,
#    26,
#    20,
#    26,
#    42,
#    22,
#    13,
#    17,
#    20,
#    17,
#    21,
#    22,
#    12]},
#  'sampler_perf': {'mean_raw_obs_processing_ms': 1.9392986278552988,
#   'mean_inference_ms': 2.3113059235381317,
#   'mean_action_processing_ms': 0.32740730148452624,
#   'mean_env_wait_ms': 0.14817702782142175,
#   'mean_env_render_ms': 0.0},
#  'num_faulty_episodes': 0,
#  'connector_metrics': {'ObsPreprocessorConnector_ms': 0.009781973702566964,
#   'StateBufferConnector_ms': 0.029928343636648997,
#   'ViewRequirementAgentConnector_ms': 0.3139816984838369},
#  'num_healthy_workers': 1,
#  'num_in_flight_async_reqs': 0,
#  'num_remote_worker_restarts': 0,
#  'num_agent_steps_sampled': 1000,
#  'num_agent_steps_trained': 0,
#  'num_env_steps_sampled': 1000,
#  'num_env_steps_trained': 0,
#  'num_env_steps_sampled_this_iter': 1000,
#  'num_env_steps_trained_this_iter': 0,
#  'num_env_steps_sampled_throughput_per_sec': 90.204565211636,
#  'num_env_steps_trained_throughput_per_sec': 0.0,
#  'timesteps_total': 1000,
#  'num_steps_trained_this_iter': 0,
#  'agent_timesteps_total': 1000,
#  'timers': {'training_iteration_time_ms': 15.092, 'sample_time_ms': 14.256},
#  'counters': {'num_env_steps_sampled': 1000,
#   'num_env_steps_trained': 0,
#   'num_agent_steps_sampled': 1000,
#   'num_agent_steps_trained': 0},
#  'done': False,
#  'episodes_total': 49,
#  'training_iteration': 1,
#  'trial_id': 'default',
#  'date': '2024-04-11_16-36-40',
#  'timestamp': 1712833600,
#  'time_this_iter_s': 11.096002340316772,
#  'time_total_s': 11.096002340316772,
#  'pid': 8596,
#  'hostname': 'Ritwik',
#  'node_ip': '127.0.0.1',
#  'config': {'extra_python_environs_for_driver': {},
#   'extra_python_environs_for_worker': {},
#   'num_gpus': 0,
#   'num_cpus_per_worker': 1,
#   'num_gpus_per_worker': 0,
#   '_fake_gpus': False,
#   'num_learner_workers': 0,
#   'num_gpus_per_learner_worker': 0,
#   'num_cpus_per_learner_worker': 1,
#   'local_gpu_idx': 0,
#   'custom_resources_per_worker': {},
#   'placement_strategy': 'PACK',
#   'eager_tracing': True,
#   'eager_max_retraces': 20,
#   'tf_session_args': {'intra_op_parallelism_threads': 2,
#    'inter_op_parallelism_threads': 2,
#    'gpu_options': {'allow_growth': True},
#    'log_device_placement': False,
#    'device_count': {'CPU': 1},
#    'allow_soft_placement': True},
#   'local_tf_session_args': {'intra_op_parallelism_threads': 8,
#    'inter_op_parallelism_threads': 8},
#   'torch_compile_learner': False,
#   'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#   'torch_compile_learner_dynamo_backend': 'inductor',
#   'torch_compile_learner_dynamo_mode': None,
#   'torch_compile_worker': False,
#   'torch_compile_worker_dynamo_backend': 'onnxrt',
#   'torch_compile_worker_dynamo_mode': None,
#   'env': 'CartPole-v1',
#   'env_config': {},
#   'observation_space': None,
#   'action_space': None,
#   'env_task_fn': None,
#   'render_env': False,
#   'clip_rewards': None,
#   'normalize_actions': True,
#   'clip_actions': False,
#   'disable_env_checking': False,
#   'auto_wrap_old_gym_envs': True,
#   'action_mask_key': 'action_mask',
#   '_is_atari': None,
#   'env_runner_cls': None,
#   'num_envs_per_worker': 1,
#   'enable_connectors': True,
#   '_env_to_module_connector': None,
#   '_module_to_env_connector': None,
#   'add_default_connectors_to_env_to_module_pipeline': True,
#   'add_default_connectors_to_module_to_env_pipeline': True,
#   'episode_lookback_horizon': 1,
#   'rollout_fragment_length': 'auto',
#   'batch_mode': 'truncate_episodes',
#   'validate_workers_after_construction': True,
#   'compress_observations': False,
#   'sampler_perf_stats_ema_coef': None,
#   'sample_async': -1,
#   'remote_worker_envs': False,
#   'remote_env_batch_wait_ms': 0,
#   'enable_tf1_exec_eagerly': False,
#   'sample_collector': ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector,
#   'preprocessor_pref': 'deepmind',
#   'observation_filter': 'NoFilter',
#   'update_worker_filter_stats': True,
#   'use_worker_filter_stats': True,
#   'gamma': 0.95,
#   'lr': 0.0005,
#   'grad_clip': 40.0,
#   'grad_clip_by': 'global_norm',
#   'train_batch_size': 32,
#   'train_batch_size_per_learner': None,
#   'model': {'_disable_preprocessor_api': False,
#    '_disable_action_flattening': False,
#    'fcnet_hiddens': [256, 256],
#    'fcnet_activation': 'tanh',
#    'fcnet_weights_initializer': None,
#    'fcnet_weights_initializer_config': None,
#    'fcnet_bias_initializer': None,
#    'fcnet_bias_initializer_config': None,
#    'conv_filters': None,
#    'conv_activation': 'relu',
#    'conv_kernel_initializer': None,
#    'conv_kernel_initializer_config': None,
#    'conv_bias_initializer': None,
#    'conv_bias_initializer_config': None,
#    'conv_transpose_kernel_initializer': None,
#    'conv_transpose_kernel_initializer_config': None,
#    'conv_transpose_bias_initializer': None,
#    'conv_transpose_bias_initializer_config': None,
#    'post_fcnet_hiddens': [],
#    'post_fcnet_activation': 'relu',
#    'post_fcnet_weights_initializer': None,
#    'post_fcnet_weights_initializer_config': None,
#    'post_fcnet_bias_initializer': None,
#    'post_fcnet_bias_initializer_config': None,
#    'free_log_std': False,
#    'no_final_linear': False,
#    'vf_share_layers': True,
#    'use_lstm': False,
#    'max_seq_len': 20,
#    'lstm_cell_size': 256,
#    'lstm_use_prev_action': False,
#    'lstm_use_prev_reward': False,
#    'lstm_weights_initializer': None,
#    'lstm_weights_initializer_config': None,
#    'lstm_bias_initializer': None,
#    'lstm_bias_initializer_config': None,
#    '_time_major': False,
#    'use_attention': False,
#    'attention_num_transformer_units': 1,
#    'attention_dim': 64,
#    'attention_num_heads': 1,
#    'attention_head_dim': 32,
#    'attention_memory_inference': 50,
#    'attention_memory_training': 50,
#    'attention_position_wise_mlp_dim': 32,
#    'attention_init_gru_gate_bias': 2.0,
#    'attention_use_n_prev_actions': 0,
#    'attention_use_n_prev_rewards': 0,
#    'framestack': True,
#    'dim': 84,
#    'grayscale': False,
#    'zero_mean': True,
#    'custom_model': None,
#    'custom_model_config': {},
#    'custom_action_dist': None,
#    'custom_preprocessor': None,
#    'encoder_latent_dim': None,
#    'always_check_shapes': False,
#    'lstm_use_prev_action_reward': -1,
#    '_use_default_native_models': -1},
#   '_learner_connector': None,
#   'add_default_connectors_to_learner_pipeline': True,
#   'optimizer': {},
#   'max_requests_in_flight_per_sampler_worker': 2,
#   '_learner_class': None,
#   'explore': True,
#   'exploration_config': {'type': 'EpsilonGreedy',
#    'initial_epsilon': 1,
#    'final_epsilon': 0.01,
#    'epsilon_timesteps': 20000},
#   'algorithm_config_overrides_per_module': {},
#   '_per_module_overrides': {},
#   'count_steps_by': 'env_steps',
#   'policy_map_capacity': 100,
#   'policy_mapping_fn': <function ray.rllib.algorithms.algorithm_config.AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN(aid, episode, worker, **kwargs)>,
#   'policies_to_train': None,
#   'policy_states_are_swappable': False,
#   'observation_fn': None,
#   'input_config': {},
#   'actions_in_input_normalized': False,
#   'postprocess_inputs': False,
#   'shuffle_buffer_size': 0,
#   'output': None,
#   'output_config': {},
#   'output_compress_columns': ['obs', 'new_obs'],
#   'output_max_file_size': 67108864,
#   'offline_sampling': False,
#   'evaluation_interval': None,
#   'evaluation_duration': 10,
#   'evaluation_duration_unit': 'episodes',
#   'evaluation_sample_timeout_s': 180.0,
#   'evaluation_parallel_to_training': False,
#   'evaluation_config': {'explore': False},
#   'off_policy_estimation_methods': {},
#   'ope_split_batch_by_episode': True,
#   'evaluation_num_workers': 1,
#   'custom_async_evaluation_function': None,
#   'always_attach_evaluation_results': False,
#   'enable_async_evaluation': False,
#   'in_evaluation': False,
#   'sync_filters_on_rollout_workers_timeout_s': 60.0,
#   'keep_per_episode_custom_metrics': False,
#   'metrics_episode_collection_timeout_s': 60.0,
#   'metrics_num_episodes_for_smoothing': 100,
#   'min_time_s_per_iteration': None,
#   'min_train_timesteps_per_iteration': 0,
#   'min_sample_timesteps_per_iteration': 1000,
#   'export_native_model_files': False,
#   'checkpoint_trainable_policies_only': False,
#   'logger_creator': None,
#   'logger_config': None,
#   'log_level': 'WARN',
#   'log_sys_usage': True,
#   'fake_sampler': False,
#   'seed': None,
#   'ignore_worker_failures': False,
#   'recreate_failed_workers': False,
#   'max_num_worker_restarts': 1000,
#   'delay_between_worker_restarts_s': 60.0,
#   'restart_failed_sub_environments': False,
#   'num_consecutive_worker_failures_tolerance': 100,
#   'worker_health_probe_timeout_s': 60,
#   'worker_restore_timeout_s': 1800,
#   '_rl_module_spec': None,
#   '_AlgorithmConfig__prior_exploration_config': None,
#   '_enable_new_api_stack': False,
#   '_tf_policy_handles_more_than_one_loss': False,
#   '_disable_preprocessor_api': False,
#   '_disable_action_flattening': False,
#   '_disable_initialize_loss_from_dummy_batch': False,
#   'simple_optimizer': False,
#   'policy_map_cache': -1,
#   'worker_cls': -1,
#   'synchronize_filters': -1,
#   'replay_sequence_length': None,
#   '_disable_execution_plan_api': -1,
#   'target_network_update_freq': 500,
#   'replay_buffer_config': {'type': ray.rllib.utils.replay_buffers.multi_agent_prioritized_replay_buffer.MultiAgentPrioritizedReplayBuffer,
#    'prioritized_replay': -1,
#    'capacity': 50000,
#    'prioritized_replay_alpha': 0.6,
#    'prioritized_replay_beta': 0.4,
#    'prioritized_replay_eps': 1e-06,
#    'replay_sequence_length': 1,
#    'worker_side_prioritization': False},
#   'num_steps_sampled_before_learning_starts': 1000,
#   'store_buffer_in_checkpoints': False,
#   'lr_schedule': None,
#   'adam_epsilon': 1e-08,
#   'tau': 1.0,
#   'num_atoms': 1,
#   'v_min': -10.0,
#   'v_max': 10.0,
#   'noisy': False,
#   'sigma0': 0.5,
#   'dueling': True,
#   'hiddens': [512, 512],
#   'double_q': True,
#   'n_step': 1,
#   'before_learn_on_batch': None,
#   'training_intensity': None,
#   'td_error_loss_fn': 'huber',
#   'categorical_distribution_temperature': 1.0,
#   'input': 'sampler',
#   'policies': {'default_policy': (None, None, None, None)},
#   'callbacks': ray.rllib.algorithms.callbacks.DefaultCallbacks,
#   'create_env_on_driver': False,
#   'custom_eval_function': None,
#   'framework': 'tf',
#   'num_cpus_for_driver': 1,
#   'num_workers': 1},
#  'time_since_restore': 11.096002340316772,
#  'iterations_since_restore': 1,
#  'perf': {'cpu_util_percent': 15.376470588235293,
#   'ram_util_percent': 68.34117647058824}}

# %%
# Recall the last trained agent
agent_name_list = os.listdir('DQN_agents')
agent_name_list_in_int = [int(x) for x in agent_name_list]
last_agent_num = max(agent_name_list_in_int)
check_point = 'DQN_agents/' + str(last_agent_num)
agent = Algorithm.from_checkpoint(check_point)

# Recall the log data frame
logs = pd.read_csv('DQN_logs/logs')

training_range = 300

for i in range(last_agent_num, (last_agent_num + training_range)):
    # Train the agent
    result = agent.train()
    # Save the agent
    check_point_path_name = 'DQN_agents/' + str(i+1)
    agent.save(check_point_path_name)
    # Capture the log    
    #print(pretty_print(result)) # It gives all the parameters regarding the training
    logs.at[i,'agent_name'] = str(i+1)
    logs.at[i,'itr_steps'] = result['num_env_steps_sampled_this_iter']
    logs.at[i,'rew_mean'] = result['episode_reward_mean']
    logs.at[i,'rew_max'] = result['episode_reward_max']
    logs.at[i,'rew_min'] = result['episode_reward_min']
    
    #print(logs)
    logs.to_csv('DQN_logs/logs', index=False)
# Out:
# 2024-04-11 16:36:40,651	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=1396) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=1396)   "class": algorithms.Blowfish,
# 2024-04-11 16:37:01,753	WARNING algorithm_config.py:3824 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (pid=13128) C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
# (pid=13128)   "class": algorithms.Blowfish,
# 2024-04-11 16:37:16,313	INFO trainable.py:164 -- Trainable.setup took 35.649 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-04-11 16:37:16,316	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=1396) WARNING:tensorflow:From C:\Users\ritwi\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\exploration\epsilon_greedy.py:242: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (RolloutWorker pid=1396) Instructions for updating:
# (RolloutWorker pid=1396) Prefer Variable.assign which has equivalent behavior in 2.X.
# (RolloutWorker pid=284)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 15
#      11 training_range = 300
#      13 for i in range(last_agent_num, (last_agent_num + training_range)):
#      14     # Train the agent
# ---> 15     result = agent.train()
#      16     # Save the agent
#      17     check_point_path_name = 'DQN_agents/' + str(i+1)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\tune\trainable\trainable.py:331, in Trainable.train(self)
#     329 start = time.time()
#     330 try:
# --> 331     result = self.step()
#     332 except Exception as e:
#     333     skipped = skip_exceptions(e)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:849, in Algorithm.step(self)
#     841     (
#     842         results,
#     843         train_iter_ctx,
#     844     ) = self._run_one_training_iteration_and_evaluation_in_parallel()
#     845 # - No evaluation necessary, just run the next training iteration.
#     846 # - We have to evaluate in this training iteration, but no parallelism ->
#     847 #   evaluate after the training iteration is entirely done.
#     848 else:
# --> 849     results, train_iter_ctx = self._run_one_training_iteration()
#     851 # Sequential: Train (already done above), then evaluate.
#     852 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:3194, in Algorithm._run_one_training_iteration(self)
#    3191     while not train_iter_ctx.should_stop(results):
#    3192         # Try to train one step.
#    3193         with self._timers[TRAINING_ITERATION_TIMER]:
# -> 3194             results = self.training_step()
#    3196 # With training step done. Try to bring failed workers back.
#    3197 self.restore_workers(self.workers)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\dqn\dqn.py:410, in DQN.training_step(self)
#     407 if cur_ts > self.config.num_steps_sampled_before_learning_starts:
#     408     for _ in range(sample_and_train_weight):
#     409         # Sample training batch (MultiAgentBatch) from replay buffer.
# --> 410         train_batch = sample_min_n_steps_from_buffer(
#     411             self.local_replay_buffer,
#     412             self.config.train_batch_size,
#     413             count_by_agent_steps=self.config.count_steps_by == "agent_steps",
#     414         )
#     416         # Postprocess batch before we learn on it
#     417         post_fn = self.config.get("before_learn_on_batch") or (lambda b, *a: b)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\replay_buffers\utils.py:189, in sample_min_n_steps_from_buffer(replay_buffer, min_steps, count_by_agent_steps)
#     187 train_batches = []
#     188 while train_batch_size < min_steps:
# --> 189     batch = replay_buffer.sample(num_items=1)
#     190     batch_len = batch.agent_steps() if count_by_agent_steps else batch.env_steps()
#     191     if batch_len == 0:
#     192         # Replay has not started, so we can't accumulate timesteps here
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\replay_buffers\multi_agent_replay_buffer.py:331, in MultiAgentReplayBuffer.sample(self, num_items, policy_id, **kwargs)
#     329 samples = {}
#     330 for policy_id, replay_buffer in self.replay_buffers.items():
# --> 331     samples[policy_id] = replay_buffer.sample(num_items, **kwargs)
#     332 return MultiAgentBatch(samples, sum(s.count for s in samples.values()))
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\replay_buffers\prioritized_replay_buffer.py:154, in PrioritizedReplayBuffer.sample(self, num_items, beta, **kwargs)
#     152     batch_indexes.extend([idx] * actual_size)
#     153     self._num_timesteps_sampled += count
# --> 154 batch = self._encode_sample(idxes)
#     156 # Note: prioritization is not supported in multi agent lockstep
#     157 if isinstance(batch, SampleBatch):
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\replay_buffers\replay_buffer.py:370, in ReplayBuffer._encode_sample(self, idxes)
#     366     samples.append(self._storage[i])
#     368 if samples:
#     369     # We assume all samples are of same type
# --> 370     out = concat_samples(samples)
#     371 else:
#     372     out = SampleBatch()
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\policy\sample_batch.py:1641, in concat_samples(samples)
#    1639         values_to_concat = [c[k] for c in concated_samples]
#    1640         _concat_values_w_time = partial(_concat_values, time_major=time_major)
# -> 1641         concatd_data[k] = tree.map_structure(
#    1642             _concat_values_w_time, *values_to_concat
#    1643         )
#    1645 if concatd_seq_lens != [] and torch and torch.is_tensor(concatd_seq_lens[0]):
#    1646     concatd_seq_lens = torch.Tensor(concatd_seq_lens)
#
# File ~\anaconda3\envs\ray\lib\site-packages\tree\__init__.py:435, in map_structure(func, *structures, **kwargs)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File ~\anaconda3\envs\ray\lib\site-packages\tree\__init__.py:435, in <listcomp>(.0)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\policy\sample_batch.py:1739, in _concat_values(time_major, *values)
#    1737     return torch.cat(values, dim=1 if time_major else 0)
#    1738 elif isinstance(values[0], np.ndarray):
# -> 1739     return np.concatenate(values, axis=1 if time_major else 0)
#    1740 elif tf and tf.is_tensor(values[0]):
#    1741     return tf.concat(values, axis=1 if time_major else 0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
logs = pd.read_csv('DQN_logs/logs')

# Plotting Column1 and Column2 with Time as the x-axis
plt.plot(logs['agent_name'], logs['rew_mean'], label='rew_mean')
plt.plot(logs['agent_name'], logs['rew_max'], label='rew_max')
plt.plot(logs['agent_name'], logs['rew_min'], label='rew_min')

# Adding labels and legend
plt.xlabel('Iteration_Steps')
plt.ylabel('Values')
plt.legend()

# Display the plot
plt.show()

# %%
# recall and trained agent
check_point = "DQN_agents/69"
agent = Algorithm.from_checkpoint(check_point)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 # recall and trained agent
#       2 check_point = "DQN_agents/70"
# ----> 3 agent = Algorithm.from_checkpoint(check_point)
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\algorithms\algorithm.py:308, in Algorithm.from_checkpoint(checkpoint, policy_ids, policy_mapping_fn, policies_to_train)
#     274 @staticmethod
#     275 def from_checkpoint(
#     276     checkpoint: Union[str, Checkpoint],
#    (...)
#     284     ] = None,
#     285 ) -> "Algorithm":
#     286     """Creates a new algorithm instance from a given checkpoint.
#     287
#     288     Note: This method must remain backward compatible from 2.0.0 on.
#    (...)
#     306         The instantiated Algorithm.
#     307     """
# --> 308     checkpoint_info = get_checkpoint_info(checkpoint)
#     310     # Not possible for (v0.1) (algo class and config information missing
#     311     # or very hard to retrieve).
#     312     if checkpoint_info["checkpoint_version"] == version.Version("0.1"):
#
# File ~\anaconda3\envs\ray\lib\site-packages\ray\rllib\utils\checkpoints.py:171, in get_checkpoint_info(checkpoint)
#     162     info.update(
#     163         {
#     164             "checkpoint_version": version.Version("0.1"),
#    (...)
#     167         }
#     168     )
#     170 else:
# --> 171     raise ValueError(
#     172         f"Given checkpoint ({checkpoint}) not found! Must be a "
#     173         "checkpoint directory (or a file for older checkpoint versions)."
#     174     )
#     176 return info
#
# ValueError: Given checkpoint (DQN_agents/70) not found! Must be a checkpoint directory (or a file for older checkpoint versions).

# %%
# use the restored agent in the environment
env = gym.make("CartPole-v1", render_mode='human')
for j in range(20):
    observation = np.array(env.reset()[0])
    done = False
    score = 0
    while not done:
        action = agent.compute_single_action(observation) # here is the RL agent from RAYRLlib
        observation,reward,done,info,info = env.step(action)
        score += reward
        if (score>1000):
            done = True
    print("score:",score)
env.close()
